# %% [markdown]
# # 🔹UFC Fight Predictor v2 EDA [Exploratory Data Analysis]

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# # Import Libraries and Setup Environment

# %%
# Import necessary libraries
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import logging
logging.basicConfig(level=logging.INFO, format='[%(levelname)s] %(message)s')
logger = logging.getLogger(__name__)

# Get the current working directory
current_dir = os.getcwd()

# Navigate to the project root
project_root = os.path.abspath(os.path.join(current_dir, '..'))

# Import from /src
sys.path.append(os.path.join(project_root))
from src.data import UFCData

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# # Load Data

# %%
# Load the cleaned dataset
file_path = os.path.abspath(os.path.join(project_root, 'data', 'processed', 'ufc_etl.csv'))

# Load the CSV into a DataFrame
try:
    ufc_df = pd.read_csv(file_path)
    logger.info(f"✅ Data successfully loaded: {ufc_df.shape[0]} rows, {ufc_df.shape[1]} columns.")
except Exception as e:
    logger.error(f"❌ Error loading training data: {e}")
# Out:
# [INFO] ✅ Data successfully loaded: 7704 rows, 193 columns.

# %% [markdown]
# # Initialize UFCData object

# %%
ufc_data = UFCData(ufc_df)
ufc_data
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples       : 7704
# 🧪 Train/Test split    : 6163 / 1541
# 🧪 Total features      : 192
#
# 🔢 Numerical features  : 172
# 🔠 Categorical features: 20
#     - Binary           : 3
#     - Multiclass       : 17
#
# 🔠 Categorical feature names (all):
#       b_dob, b_id, b_name, b_stance, date, division, event_id, event_name, fight_id, location,
#       method, r_dob, r_id, r_name, r_stance, title_fight, total_rounds, winner, winner_corner,
#       winner_id
#
#    • Binary categorical features:
#       title_fight, total_rounds, winner_corner
#
#    • Multiclass categorical features:
#       b_dob, b_id, b_name, b_stance, date, division, event_id, event_name, fight_id, location,
#       method, r_dob, r_id, r_name, r_stance, winner, winner_id
#
# 🏷 Label distribution (raw):
#    - Class 0: 4890 (63.5%)
#    - Class 1: 2814 (36.5%)
#
# ⚠️ Missing values      : 3181 total
#
# 📈 Feature summary statistics (train set):
#                              mean       std      min       max
# finish_round                2.384     1.008    1.000     5.000
# match_time_sec            227.748    91.892    5.000   300.000
# r_kd                        0.255     0.529    0.000     5.000
# r_sig_str_landed           39.800    33.386    0.000   445.000
# r_sig_str_atmpted          86.769    71.883    0.000   744.000
# r_sig_str_acc              47.775    15.929    0.000   100.000
# r_total_str_landed         59.564    46.078    0.000   447.000
# r_total_str_atmpted       109.466    80.007    0.000   746.000
# r_total_str_acc            55.049    16.982    0.000   100.000
# r_td_landed                 1.215     1.811    0.000    21.000
# r_td_atmpted                2.986     3.777    0.000    30.000
# r_sub_att                   0.419     0.858    0.000    10.000
# r_ctrl                    152.691   189.541    0.000  1342.000
# r_head_landed              25.297    23.290    0.000   274.000
# r_head_atmpted             67.282    58.382    0.000   553.000
# r_head_acc                 38.945    17.600    0.000   100.000
# r_body_landed               8.159     9.051    0.000   117.000
# r_body_atmpted             11.654    12.361    0.000   133.000
# r_body_acc                 63.838    30.946    0.000   100.000
# r_leg_landed                6.345     8.159    0.000    78.000
# r_leg_atmpted               7.833    10.026    0.000   101.000
# r_leg_acc                  67.129    37.622    0.000   100.000
# r_dist_landed              28.695    30.463    0.000   439.000
# r_dist_atmpted             70.862    69.624    0.000   737.000
# r_dist_acc                 40.175    16.722    0.000   100.000
# r_clinch_landed             5.238     7.645    0.000    95.000
# r_clinch_atmpted            7.417    10.279    0.000   115.000
# r_clinch_acc               53.134    37.748    0.000   100.000
# r_ground_landed             5.867     9.655    0.000    88.000
# r_ground_atmpted            8.490    13.931    0.000   136.000
# r_ground_acc               45.521    39.782    0.000   100.000
# r_landed_head_per          62.536    22.259    0.000   100.000
# r_landed_body_per          19.731    15.283    0.000   100.000
# r_landed_leg_per           16.645    17.464    0.000   100.000
# r_landed_dist_per          66.438    29.119    0.000   100.000
# r_landed_clinch_per        13.775    17.255    0.000   100.000
# r_landed_ground_per        18.859    25.636    0.000   100.000
# r_height                  178.375     9.063  152.400   210.820
# r_weight                   75.473    15.968   52.160   120.200
# r_reach                   183.072    10.996  147.320   213.360
# r_td_avg_acc               38.817    17.834    0.000   100.000
# b_kd                        0.188     0.464    0.000     4.000
# b_sig_str_landed           35.410    31.519    0.000   241.000
# b_sig_str_atmpted          82.008    69.718    0.000   510.000
# b_sig_str_acc              43.931    16.704    0.000   100.000
# b_total_str_landed         51.831    42.136    0.000   331.000
# b_total_str_atmpted       100.841    76.909    0.000   556.000
# b_total_str_acc            51.656    17.904    0.000   100.000
# b_td_landed                 0.915     1.538    0.000    12.000
# b_td_atmpted                2.716     3.755    0.000    49.000
# b_sub_att                   0.322     0.758    0.000     7.000
# b_ctrl                    113.639   153.780    0.000  1193.000
# b_head_landed              22.151    22.130    0.000   187.000
# b_head_atmpted             63.832    57.195    0.000   437.000
# b_head_acc                 34.232    17.825    0.000   100.000
# b_body_landed               7.326     8.259    0.000    92.000
# b_body_atmpted             10.763    11.459    0.000   112.000
# b_body_acc                 60.766    31.786    0.000   100.000
# b_leg_landed                5.933     7.572    0.000    77.000
# b_leg_atmpted               7.413     9.302    0.000    91.000
# b_leg_acc                  65.896    37.728    0.000   100.000
# b_dist_landed              26.779    28.250    0.000   225.000
# b_dist_atmpted             69.487    66.595    0.000   504.000
# b_dist_acc                 37.718    16.803    0.000   100.000
# b_clinch_landed             4.767     6.795    0.000    66.000
# b_clinch_atmpted            6.917     9.261    0.000    89.000
# b_clinch_acc               51.180    37.797    0.000   100.000
# b_ground_landed             3.864     8.048    0.000   136.000
# b_ground_atmpted            5.605    11.192    0.000   163.000
# b_ground_acc               38.012    40.447    0.000   100.000
# b_landed_head_per          58.720    24.827    0.000   100.000
# b_landed_body_per          20.098    17.044    0.000   100.000
# b_landed_leg_per           17.993    19.473    0.000   100.000
# b_landed_dist_per          69.998    28.726    0.000   100.000
# b_landed_clinch_per        14.422    18.688    0.000   100.000
# b_landed_ground_per        12.575    21.310    0.000   100.000
# b_height                  178.254     9.012  152.400   210.820
# b_weight                   75.247    15.865   52.160   120.200
# b_reach                   182.604    10.837  147.320   213.360
# b_td_avg_acc               36.507    20.155    0.000   100.000
# r_wins                      4.168     4.171    0.000    27.000
# r_losses                    2.292     2.483    0.000    18.000
# r_draws                     0.051     0.238    0.000     2.000
# r_total_fights              6.511     6.249    0.000    44.000
# r_current_win_streak        1.040     1.693    0.000    18.000
# r_current_lose_streak       0.576     0.827    0.000     7.000
# r_longest_win_streak        2.489     2.194    0.000    18.000
# r_longest_lose_streak       1.199     0.982    0.000     7.000
# r_momentum                  0.757     1.762   -5.000     5.000
# r_momentum_ema              0.122     0.518   -0.984     1.000
# b_wins                      2.888     3.460    0.000    26.000
# b_losses                    1.688     2.019    0.000    16.000
# b_draws                     0.036     0.192    0.000     2.000
# b_total_fights              4.612     5.137    0.000    42.000
# b_current_win_streak        0.938     1.407    0.000    12.000
# b_current_lose_streak       0.453     0.745    0.000     5.000
# b_longest_win_streak        1.806     1.885    0.000    16.000
# b_longest_lose_streak       0.991     0.936    0.000     5.000
# b_momentum                  0.605     1.657   -5.000     5.000
# b_momentum_ema              0.127     0.496   -0.953     1.000
# r_wins_ko                   1.465     1.984    0.000    15.000
# r_wins_sub                  0.852     1.490    0.000    16.000
# r_wins_dec                  1.843     2.238    0.000    14.000
# r_losses_ko                 0.680     1.091    0.000     8.000
# r_losses_sub                0.449     0.863    0.000     7.000
# r_losses_dec                1.156     1.537    0.000    12.000
# b_wins_ko                   1.017     1.661    0.000    14.000
# b_wins_sub                  0.595     1.185    0.000    14.000
# b_wins_dec                  1.271     1.801    0.000    12.000
# b_losses_ko                 0.499     0.883    0.000     8.000
# b_losses_sub                0.336     0.720    0.000     6.000
# b_losses_dec                0.849     1.296    0.000    11.000
# r_age                      30.093     4.264   18.000    46.000
# b_age                      29.722     4.017   18.000    47.000
# r_days_since_last_fight   217.726   190.912    7.000  3199.000
# r_days_since_debut       1244.485  1203.352    0.000  8401.000
# b_days_since_last_fight   223.886   229.483   14.000  4180.000
# b_days_since_debut        905.738  1007.904    0.000  7078.000
# r_SLpM                     12.352    18.826    0.000   677.143
# r_Str_Acc                  47.775    15.929    0.000   100.000
# r_SApM                     10.641    15.803    0.000   480.000
# r_Str_Def                  55.728    16.824    0.000   100.000
# r_TD_Avg                    5.549    13.302    0.000   514.286
# r_TD_Acc                   29.750    36.347    0.000   100.000
# r_TD_Def                   40.188    41.809    0.000   100.000
# r_Sub_Avg                   2.241     6.153    0.000   128.571
# b_SLpM                     10.641    15.803    0.000   480.000
# b_Str_Acc                  43.931    16.704    0.000   100.000
# b_SApM                     12.352    18.826    0.000   677.143
# b_Str_Def                  51.933    15.967    0.000   100.000
# b_TD_Avg                    4.123    10.258    0.000   270.000
# b_TD_Acc                   22.915    33.324    0.000   100.000
# b_TD_Def                   38.107    39.872    0.000   100.000
# b_Sub_Avg                   1.608     4.866    0.000    90.000
# r_TSLpM                    17.970    25.795    0.000   960.000
# r_TStr_Acc                 55.049    16.982    0.000   100.000
# r_CtrlpM                   44.995    92.754    0.000  3771.429
# r_HeadSLpM                  8.058    13.236    0.000   445.714
# r_BodySLpM                  2.404     4.197    0.000   128.571
# r_LegSLpM                   1.890     3.691    0.000   102.857
# r_DistSLpM                  8.617    15.235    0.000   591.429
# r_ClinchSLpM                1.637     3.583    0.000    85.714
# r_GroundSLpM                2.097     5.049    0.000   127.200
# b_TSLpM                    15.350    20.964    0.000   531.429
# b_TStr_Acc                 51.656    17.904    0.000   100.000
# b_CtrlpM                   33.409    67.290    0.000  1913.333
# b_HeadSLpM                  6.754    10.951    0.000   342.857
# b_BodySLpM                  2.162     4.053    0.000   111.429
# b_LegSLpM                   1.726     3.046    0.000    90.909
# b_DistSLpM                  7.866    12.939    0.000   368.571
# b_ClinchSLpM                1.436     3.195    0.000    85.714
# b_GroundSLpM                1.340     4.055    0.000   130.435
# r_TSApM                    15.350    20.964    0.000   531.429
# r_TStr_Def                 48.166    17.886    0.000   100.000
# r_OpCtrlpM                 33.409    67.290    0.000  1913.333
# r_HeadSApM                  6.754    10.951    0.000   342.857
# r_BodySApM                  2.162     4.053    0.000   111.429
# r_LegSApM                   1.726     3.046    0.000    90.909
# r_DistSApM                  7.866    12.939    0.000   368.571
# r_ClinchSApM                1.436     3.195    0.000    85.714
# r_GroundSApM                1.340     4.055    0.000   130.435
# b_TSApM                    17.970    25.795    0.000   960.000
# b_TStr_Def                 44.772    16.928    0.000   100.000
# b_OpCtrlpM                 44.995    92.754    0.000  3771.429
# b_HeadSApM                  8.058    13.236    0.000   445.714
# b_BodySApM                  2.404     4.197    0.000   128.571
# b_LegSApM                   1.890     3.691    0.000   102.857
# b_DistSApM                  8.617    15.235    0.000   591.429
# b_ClinchSApM                1.637     3.583    0.000    85.714
# b_GroundSApM                2.097     5.049    0.000   127.200
# r_td_acc                   29.750    36.347    0.000   100.000
# b_td_acc                   22.915    33.324    0.000   100.000
#
# ⚙️ Preprocessing status:
#    - Standardized?     : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# # Initial Data Exploration

# %%
# View the first few rows of the training data
ufc_df.head()
# Out:
#            event_id                       event_name        date  \
# 0  2b1587a3376ab743  UFC 30: Battle on the Boardwalk  2001-02-23
# 1  2b1587a3376ab743  UFC 30: Battle on the Boardwalk  2001-02-23
# 2  2b1587a3376ab743  UFC 30: Battle on the Boardwalk  2001-02-23
# 3  2b1587a3376ab743  UFC 30: Battle on the Boardwalk  2001-02-23
# 4  2b1587a3376ab743  UFC 30: Battle on the Boardwalk  2001-02-23
#
#                          location          fight_id           division  \
# 0  Atlantic City, New Jersey, USA  f8820294bbe01486  light heavyweight
# 1  Atlantic City, New Jersey, USA  a38ec65ac140fcf8        lightweight
# 2  Atlantic City, New Jersey, USA  74d0da1f9df17b9e       welterweight
# 3  Atlantic City, New Jersey, USA  75a401066ad784f6        heavyweight
# 4  Atlantic City, New Jersey, USA  4a1f37200bc69376       middleweight
#
#   title_fight                method  finish_round  match_time_sec  ...  \
# 0         Yes                KO/TKO             1              32  ...
# 1         Yes  Decision - Unanimous             5             300  ...
# 2          No            Submission             1             100  ...
# 3          No                KO/TKO             2             261  ...
# 4          No            Submission             1             172  ...
#
#   b_TStr_Def b_OpCtrlpM b_HeadSApM  b_BodySApM  b_LegSApM  b_DistSApM  \
# 0      0.000      1.875      7.500       3.750      1.875       1.875
# 1     44.324     44.000      7.600       1.200      1.200       6.200
# 2     50.000     30.600      0.000       1.200      0.600       1.200
# 3     61.111      0.230      4.138       0.690      2.299       5.287
# 4     12.500      0.000      0.000       0.349      0.349       0.698
#
#    b_ClinchSApM  b_GroundSApM  r_td_acc  b_td_acc
# 0         7.500          3.75     100.0       0.0
# 1         3.600          0.20       0.0      12.0
# 2         0.600          0.00      50.0       0.0
# 3         1.839          0.00       0.0       0.0
# 4         0.000          0.00       0.0       0.0
#
# [5 rows x 193 columns]

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## Visualizing the Distribution of the Target Variable

# %%
ufc_data.plot_label_distribution(dataset = 'test')
# Out:
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## Univariate Analysis of Features (X)

# %%
# Histograms of the predictor features
ufc_data.plot_feature_distributions(numeric_only=True)
# Out:
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## Correlation Between Features

# %%
ufc_data.compute_corr()

# %%
ufc_data.plot_corr(threshold = 0.9)

# %% [markdown]
# <div style="text-align: center;">
#      <img src="../img/ufc_logo.png" width="800" />
# </div>
