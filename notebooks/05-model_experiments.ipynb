# %% [markdown]
# # 🔹 UFC Model Experiments

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# # Import Libraries and Setup Environment

# %%
# Import necessary libraries
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_colwidth', 200) 

# Get the current working directory
current_dir = os.getcwd()

# Navigate to the project root
project_root = os.path.abspath(os.path.join(current_dir, '..'))

# Import from /src
sys.path.append(os.path.join(project_root))
from src.metrics import *
from src.model_factory import model_factory
from src.model import UFCModel
from src.data import UFCData
from src.config import *
from src.io_model import load_data, load_all_models
from src.helpers import *

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# # Load Data

# %%
# Load UFCData
try:
    ufc_data = load_data(name='ufc_data')
    ufc_data_no_odds = load_data(name='ufc_data_no_odds')
except Exception as e:
    logger.error(f"❌ Error loading training data: {e}")
# Out:
# INFO:src.io_model:📦 UFCData object loaded from: /home/mlioi/ufc-predictor/data/processed/ufc_data.pkl
# INFO:src.io_model:📦 UFCData object loaded from: /home/mlioi/ufc-predictor/data/processed/ufc_data_no_odds.pkl

# %%
ufc_data
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6001
# 🧪 Train/Test split  : 4800 / 1201
# 🧪 Total features     : 28
#
# 🔢 Numerical features : 25
# 🔠 Categorical features: 3
#     - Binary          : 2
#     - Multiclass      : 1
#
# 🏷 Label distribution (raw):
#    - Class 0: 3484 (58.1%)
#    - Class 1: 2517 (41.9%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                         mean      std      min       max
# BlueTotalTitleBouts    0.260    1.111     0.00    16.000
# RedTotalTitleBouts     0.572    1.574     0.00    16.000
# LoseStreakDif          0.059    1.012    -6.00     6.000
# WinStreakDif          -0.162    1.921   -18.00    10.000
# LongestWinStreakDif   -0.772    2.053   -12.00    14.000
# KODif                 -0.536    2.181   -21.00    14.000
# SubDif                -0.334    1.877   -15.00    10.000
# HeightDif             -0.030    6.286   -33.02    30.480
# ReachDif              -0.260    8.266   -33.02    30.480
# AgeDif                -0.611    5.181   -17.00    16.000
# SigStrDif             -2.540   19.869  -118.00   128.222
# AvgSubAttDif          -0.076    0.880    -8.40     7.800
# AvgTDDif              -0.159    1.765   -11.00    10.860
# RedTotalFights         7.345    6.809     0.00    48.000
# BlueTotalFights        5.092    5.524     0.00    45.000
# HeightReachRatioDif    0.001    0.035    -0.12     0.124
# RedFinishRate          0.466    0.357     0.00     1.000
# BlueFinishRate         0.389    0.382     0.00     1.000
# RedWinRatio            0.586    0.294     0.00     1.000
# BlueWinRatio           0.492    0.349     0.00     1.000
# RedKOPerFight          0.195    0.229     0.00     1.000
# BlueKOPerFight         0.166    0.235     0.00     1.000
# RedSubPerFight         0.120    0.192     0.00     1.000
# BlueSubPerFight        0.095    0.187     0.00     1.000
# OddsDif              179.755  525.039 -1975.00  3200.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ✅
#    - Encoded?         : ✅
#    - Correlation cached (raw)      : ✅
#    - Correlation cached (processed): ✅
# ----------------------------------------

# %%
ufc_data_no_odds
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6001
# 🧪 Train/Test split  : 4800 / 1201
# 🧪 Total features     : 27
#
# 🔢 Numerical features : 24
# 🔠 Categorical features: 3
#     - Binary          : 2
#     - Multiclass      : 1
#
# 🏷 Label distribution (raw):
#    - Class 0: 3484 (58.1%)
#    - Class 1: 2517 (41.9%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                       mean     std     min      max
# BlueTotalTitleBouts  0.260   1.111    0.00   16.000
# RedTotalTitleBouts   0.572   1.574    0.00   16.000
# LoseStreakDif        0.059   1.012   -6.00    6.000
# WinStreakDif        -0.162   1.921  -18.00   10.000
# LongestWinStreakDif -0.772   2.053  -12.00   14.000
# KODif               -0.536   2.181  -21.00   14.000
# SubDif              -0.334   1.877  -15.00   10.000
# HeightDif           -0.030   6.286  -33.02   30.480
# ReachDif            -0.260   8.266  -33.02   30.480
# AgeDif              -0.611   5.181  -17.00   16.000
# SigStrDif           -2.540  19.869 -118.00  128.222
# AvgSubAttDif        -0.076   0.880   -8.40    7.800
# AvgTDDif            -0.159   1.765  -11.00   10.860
# RedTotalFights       7.345   6.809    0.00   48.000
# BlueTotalFights      5.092   5.524    0.00   45.000
# HeightReachRatioDif  0.001   0.035   -0.12    0.124
# RedFinishRate        0.466   0.357    0.00    1.000
# BlueFinishRate       0.389   0.382    0.00    1.000
# RedWinRatio          0.586   0.294    0.00    1.000
# BlueWinRatio         0.492   0.349    0.00    1.000
# RedKOPerFight        0.195   0.229    0.00    1.000
# BlueKOPerFight       0.166   0.235    0.00    1.000
# RedSubPerFight       0.120   0.192    0.00    1.000
# BlueSubPerFight      0.095   0.187    0.00    1.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ✅
#    - Encoded?         : ✅
#    - Correlation cached (raw)      : ✅
#    - Correlation cached (processed): ✅
# ----------------------------------------

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# # Load Models

# %%
model_list = load_all_models()
# Out:
# INFO:src.io_model:📦 Model 'Logistic Regression' loaded from: /home/mlioi/ufc-predictor/models/lr_best.pkl
# INFO:src.io_model:📦 Model 'Logistic Regression' loaded from: /home/mlioi/ufc-predictor/models/lr_best_no_odds.pkl
# INFO:src.io_model:📦 Model 'Random Forest' loaded from: /home/mlioi/ufc-predictor/models/rf_best.pkl
# INFO:src.io_model:📦 Model 'Random Forest' loaded from: /home/mlioi/ufc-predictor/models/rf_best_no_odds.pkl
# INFO:src.io_model:📦 Model 'Support Vector Machine' loaded from: /home/mlioi/ufc-predictor/models/svm_best.pkl
# INFO:src.io_model:📦 Model 'Support Vector Machine' loaded from: /home/mlioi/ufc-predictor/models/svm_best_no_odds.pkl
# INFO:src.io_model:📦 Model 'K-Nearest Neighbors' loaded from: /home/mlioi/ufc-predictor/models/knn_best.pkl
# INFO:src.io_model:📦 Model 'K-Nearest Neighbors' loaded from: /home/mlioi/ufc-predictor/models/knn_best_no_odds.pkl
# INFO:src.io_model:📦 Model 'AdaBoost' loaded from: /home/mlioi/ufc-predictor/models/ab_best.pkl
# INFO:src.io_model:📦 Model 'AdaBoost' loaded from: /home/mlioi/ufc-predictor/models/ab_best_no_odds.pkl
# INFO:src.io_model:📦 Model 'Naive Bayes' loaded from: /home/mlioi/ufc-predictor/models/nb_best.pkl
# INFO:src.io_model:📦 Model 'Naive Bayes' loaded from: /home/mlioi/ufc-predictor/models/nb_best_no_odds.pkl
# INFO:src.io_model:📦 Model 'Extra Trees' loaded from: /home/mlioi/ufc-predictor/models/et_best.pkl
# INFO:src.io_model:📦 Model 'Extra Trees' loaded from: /home/mlioi/ufc-predictor/models/et_best_no_odds.pkl
# INFO:src.io_model:📦 Model 'Gradient Boosting' loaded from: /home/mlioi/ufc-predictor/models/gb_best.pkl
# INFO:src.io_model:📦 Model 'Gradient Boosting' loaded from: /home/mlioi/ufc-predictor/models/gb_best_no_odds.pkl
# INFO:src.io_model:📦 Model 'Quadratic Discriminant Analysis' loaded from: /home/mlioi/ufc-predictor/models/qda_best.pkl
# INFO:src.io_model:📦 Model 'Quadratic Discriminant Analysis' loaded from: /home/mlioi/ufc-predictor/models/qda_best_no_odds.pkl
# INFO:src.io_model:📦 Model 'Neural Network' loaded from: /home/mlioi/ufc-predictor/models/nn_best.pkl
# INFO:src.io_model:📦 Model 'Neural Network' loaded from: /home/mlioi/ufc-predictor/models/nn_best_no_odds.pkl
# INFO:src.io_model:📦 Model 'XGBoost' loaded from: /home/mlioi/ufc-predictor/models/xgb_best.pkl
# INFO:src.io_model:📦 Model 'XGBoost' loaded from: /home/mlioi/ufc-predictor/models/xgb_best_no_odds.pkl

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# # Evaluate Models

# %%
models_with_odds = [m for m in model_list if not m.is_no_odds]
models_no_odds = [m for m in model_list if m.is_no_odds]

# Evaluate metrics for WITH ODDS
for model in models_with_odds:
    model.metrics = evaluate_metrics(model, ufc_data)
    model.cm = evaluate_cm(model, ufc_data)

# Evaluate metrics for NO ODDS
for model in models_no_odds:
    model.metrics = evaluate_metrics(model, ufc_data_no_odds)
    model.cm = evaluate_cm(model, ufc_data_no_odds)

# %% [markdown]
# # Check Models

# %% [markdown]
# ## Metrics Comparison

# %%
# Compare metrics WITH ODDS
metrics_with_odds = compare_metrics(models_with_odds)
display(metrics_with_odds)
# Out:
# INFO:src.metrics:🔍 Starting comparison of models...
# INFO:src.metrics:Evaluating model: Logistic Regression
# INFO:src.metrics:Evaluating model: Random Forest
# INFO:src.metrics:Evaluating model: Support Vector Machine
# INFO:src.metrics:Evaluating model: K-Nearest Neighbors
# INFO:src.metrics:Evaluating model: AdaBoost
# INFO:src.metrics:Evaluating model: Naive Bayes
# INFO:src.metrics:Evaluating model: Extra Trees
# INFO:src.metrics:Evaluating model: Gradient Boosting
# INFO:src.metrics:Evaluating model: Quadratic Discriminant Analysis
# INFO:src.metrics:Evaluating model: Neural Network
# INFO:src.metrics:Evaluating model: XGBoost
# INFO:src.metrics:✅ Comparison completed.
#                                  Accuracy  Balanced Accuracy  Precision Red  \
# Model
# Logistic Regression                0.6636             0.6459         0.6925
# Random Forest                      0.6669             0.6430         0.6840
# Support Vector Machine             0.6669             0.6499         0.6962
# K-Nearest Neighbors                0.5945             0.5688         0.6303
# AdaBoost                           0.6553             0.6258         0.6675
# Naive Bayes                        0.6170             0.6219         0.7019
# Extra Trees                        0.6370             0.6087         0.6567
# Gradient Boosting                  0.6611             0.6396         0.6840
# Quadratic Discriminant Analysis    0.6570             0.6410         0.6908
# Neural Network                     0.6536             0.6433         0.6993
# XGBoost                            0.6578             0.6332         0.6765
#
#                                  Recall Red  F1 Red  Precision Blue  \
# Model
# Logistic Regression                  0.7561  0.7229          0.6136
# Random Forest                        0.7920  0.7340          0.6320
# Support Vector Machine               0.7561  0.7249          0.6171
# K-Nearest Neighbors                  0.7288  0.6760          0.5215
# AdaBoost                             0.8092  0.7315          0.6264
# Naive Bayes                          0.5911  0.6417          0.5358
# Extra Trees                          0.7848  0.7150          0.5924
# Gradient Boosting                    0.7733  0.7259          0.6174
# Quadratic Discriminant Analysis      0.7403  0.7147          0.6013
# Neural Network                       0.7073  0.7033          0.5887
# XGBoost                              0.7862  0.7273          0.6189
#
#                                  Recall Blue  F1 Blue  F1 Macro  ROC AUC  \
# Model
# Logistic Regression                   0.5357   0.5720    0.6475   0.7145
# Random Forest                         0.4940   0.5546    0.6443   0.7062
# Support Vector Machine                0.5437   0.5781    0.6515   0.7142
# K-Nearest Neighbors                   0.4087   0.4583    0.5671   0.6121
# AdaBoost                              0.4425   0.5186    0.6251   0.7007
# Naive Bayes                           0.6528   0.5886    0.6151   0.6618
# Extra Trees                           0.4325   0.5000    0.6075   0.6575
# Gradient Boosting                     0.5060   0.5562    0.6410   0.7023
# Quadratic Discriminant Analysis       0.5417   0.5699    0.6423   0.6959
# Neural Network                        0.5794   0.5840    0.6436   0.6968
# XGBoost                               0.4802   0.5408    0.6340   0.7068
#
#                                  Brier Score     MCC   Kappa
# Model
# Logistic Regression                   0.2138  0.2989  0.2970
# Random Forest                         0.2142  0.3006  0.2949
# Support Vector Machine                0.2113  0.3064  0.3048
# K-Nearest Neighbors                   0.2415  0.1445  0.1418
# AdaBoost                              0.2173  0.2719  0.2623
# Naive Bayes                           0.2568  0.2408  0.2367
# Extra Trees                           0.2259  0.2327  0.2258
# Gradient Boosting                     0.2140  0.2901  0.2864
# Quadratic Discriminant Analysis       0.2208  0.2870  0.2859
# Neural Network                        0.2172  0.2873  0.2873
# XGBoost                               0.2122  0.2806  0.2749

# %%
# Compare metrics NO ODDS
metrics_no_odds = compare_metrics(models_no_odds)
display(metrics_no_odds)
# Out:
# INFO:src.metrics:🔍 Starting comparison of models...
# INFO:src.metrics:Evaluating model: Logistic Regression (no_odds)
# INFO:src.metrics:Evaluating model: Random Forest (no_odds)
# INFO:src.metrics:Evaluating model: Support Vector Machine (no_odds)
# INFO:src.metrics:Evaluating model: K-Nearest Neighbors (no_odds)
# INFO:src.metrics:Evaluating model: AdaBoost (no_odds)
# INFO:src.metrics:Evaluating model: Naive Bayes (no_odds)
# INFO:src.metrics:Evaluating model: Extra Trees (no_odds)
# INFO:src.metrics:Evaluating model: Gradient Boosting (no_odds)
# INFO:src.metrics:Evaluating model: Quadratic Discriminant Analysis (no_odds)
# INFO:src.metrics:Evaluating model: Neural Network (no_odds)
# INFO:src.metrics:Evaluating model: XGBoost (no_odds)
# INFO:src.metrics:✅ Comparison completed.
#                                            Accuracy  Balanced Accuracy  \
# Model
# Logistic Regression (no_odds)                0.6278             0.5890
# Random Forest (no_odds)                      0.5828             0.5450
# Support Vector Machine (no_odds)             0.6278             0.5761
# K-Nearest Neighbors (no_odds)                0.5254             0.5101
# AdaBoost (no_odds)                           0.6070             0.5677
# Naive Bayes (no_odds)                        0.5554             0.5631
# Extra Trees (no_odds)                        0.5853             0.5494
# Gradient Boosting (no_odds)                  0.6070             0.5730
# Quadratic Discriminant Analysis (no_odds)    0.6170             0.5906
# Neural Network (no_odds)                     0.6278             0.5802
# XGBoost (no_odds)                            0.6020             0.5703
#
#                                            Precision Red  Recall Red  F1 Red  \
# Model
# Logistic Regression (no_odds)                     0.6377      0.8307  0.7215
# Random Forest (no_odds)                           0.6099      0.7805  0.6847
# Support Vector Machine (no_odds)                  0.6248      0.8981  0.7369
# K-Nearest Neighbors (no_odds)                     0.5886      0.6055  0.5969
# AdaBoost (no_odds)                                0.6240      0.8121  0.7057
# Naive Bayes (no_odds)                             0.6468      0.5151  0.5735
# Extra Trees (no_odds)                             0.6132      0.7733  0.6840
# Gradient Boosting (no_odds)                       0.6295      0.7848  0.6986
# Quadratic Discriminant Analysis (no_odds)         0.6454      0.7547  0.6958
# Neural Network (no_odds)                          0.6286      0.8766  0.7322
# XGBoost (no_odds)                                 0.6287      0.7676  0.6912
#
#                                            Precision Blue  Recall Blue  \
# Model
# Logistic Regression (no_odds)                      0.5973       0.3472
# Random Forest (no_odds)                            0.5049       0.3095
# Support Vector Machine (no_odds)                   0.6432       0.2540
# K-Nearest Neighbors (no_odds)                      0.4318       0.4147
# AdaBoost (no_odds)                                 0.5544       0.3234
# Naive Bayes (no_odds)                              0.4768       0.6111
# Extra Trees (no_odds)                              0.5093       0.3254
# Gradient Boosting (no_odds)                        0.5482       0.3611
# Quadratic Discriminant Analysis (no_odds)          0.5570       0.4266
# Neural Network (no_odds)                           0.6245       0.2837
# XGBoost (no_odds)                                  0.5371       0.3730
#
#                                            F1 Blue  F1 Macro  ROC AUC  \
# Model
# Logistic Regression (no_odds)               0.4391    0.5803   0.6291
# Random Forest (no_odds)                     0.3838    0.5342   0.5824
# Support Vector Machine (no_odds)            0.3642    0.5505   0.6276
# K-Nearest Neighbors (no_odds)               0.4231    0.5100   0.5058
# AdaBoost (no_odds)                          0.4085    0.5571   0.6158
# Naive Bayes (no_odds)                       0.5357    0.5546   0.6003
# Extra Trees (no_odds)                       0.3971    0.5406   0.5851
# Gradient Boosting (no_odds)                 0.4354    0.5670   0.6098
# Quadratic Discriminant Analysis (no_odds)   0.4831    0.5895   0.6318
# Neural Network (no_odds)                    0.3902    0.5612   0.6344
# XGBoost (no_odds)                           0.4403    0.5657   0.5994
#
#                                            Brier Score     MCC   Kappa
# Model
# Logistic Regression (no_odds)                   0.2297  0.2045  0.1889
# Random Forest (no_odds)                         0.2412  0.1016  0.0951
# Support Vector Machine (no_odds)                0.2300  0.2019  0.1660
# K-Nearest Neighbors (no_odds)                   0.3295  0.0203  0.0202
# AdaBoost (no_odds)                              0.2348  0.1555  0.1438
# Naive Bayes (no_odds)                           0.2694  0.1249  0.1214
# Extra Trees (no_odds)                           0.2414  0.1100  0.1039
# Gradient Boosting (no_odds)                     0.2369  0.1610  0.1531
# Quadratic Discriminant Analysis (no_odds)       0.2330  0.1915  0.1873
# Neural Network (no_odds)                        0.2291  0.2014  0.1734
# XGBoost (no_odds)                               0.2414  0.1527  0.1468

# %% [markdown]
# ## Best Model per Metric

# %%
# Best models WITH ODDS
best_with_odds = best_model_per_metric(metrics_with_odds)
display(best_with_odds)
# Out:
# INFO:src.metrics:🏅 Best model for Accuracy: Random Forest (0.6669)
# INFO:src.metrics:🏅 Best model for Balanced Accuracy: Support Vector Machine (0.6499)
# INFO:src.metrics:🏅 Best model for Precision Red: Naive Bayes (0.7019)
# INFO:src.metrics:🏅 Best model for Recall Red: AdaBoost (0.8092)
# INFO:src.metrics:🏅 Best model for F1 Red: Random Forest (0.7340)
# INFO:src.metrics:🏅 Best model for Precision Blue: Random Forest (0.6320)
# INFO:src.metrics:🏅 Best model for Recall Blue: Naive Bayes (0.6528)
# INFO:src.metrics:🏅 Best model for F1 Blue: Naive Bayes (0.5886)
# INFO:src.metrics:🏅 Best model for F1 Macro: Support Vector Machine (0.6515)
# INFO:src.metrics:🏅 Best model for ROC AUC: Logistic Regression (0.7145)
# INFO:src.metrics:🏅 Best model for Brier Score: Support Vector Machine (0.2113)
# INFO:src.metrics:🏅 Best model for MCC: Support Vector Machine (0.3064)
# INFO:src.metrics:🏅 Best model for Kappa: Support Vector Machine (0.3048)
#                Metric              Best Model   Value
# 0            Accuracy           Random Forest  0.6669
# 1   Balanced Accuracy  Support Vector Machine  0.6499
# 2       Precision Red             Naive Bayes  0.7019
# 3          Recall Red                AdaBoost  0.8092
# 4              F1 Red           Random Forest  0.7340
# 5      Precision Blue           Random Forest  0.6320
# 6         Recall Blue             Naive Bayes  0.6528
# 7             F1 Blue             Naive Bayes  0.5886
# 8            F1 Macro  Support Vector Machine  0.6515
# 9             ROC AUC     Logistic Regression  0.7145
# 10        Brier Score  Support Vector Machine  0.2113
# 11                MCC  Support Vector Machine  0.3064
# 12              Kappa  Support Vector Machine  0.3048

# %%
# Best models NO ODDS
best_no_odds = best_model_per_metric(metrics_no_odds)
display(best_no_odds)
# Out:
# INFO:src.metrics:🏅 Best model for Accuracy: Logistic Regression (no_odds) (0.6278)
# INFO:src.metrics:🏅 Best model for Balanced Accuracy: Quadratic Discriminant Analysis (no_odds) (0.5906)
# INFO:src.metrics:🏅 Best model for Precision Red: Naive Bayes (no_odds) (0.6468)
# INFO:src.metrics:🏅 Best model for Recall Red: Support Vector Machine (no_odds) (0.8981)
# INFO:src.metrics:🏅 Best model for F1 Red: Support Vector Machine (no_odds) (0.7369)
# INFO:src.metrics:🏅 Best model for Precision Blue: Support Vector Machine (no_odds) (0.6432)
# INFO:src.metrics:🏅 Best model for Recall Blue: Naive Bayes (no_odds) (0.6111)
# INFO:src.metrics:🏅 Best model for F1 Blue: Naive Bayes (no_odds) (0.5357)
# INFO:src.metrics:🏅 Best model for F1 Macro: Quadratic Discriminant Analysis (no_odds) (0.5895)
# INFO:src.metrics:🏅 Best model for ROC AUC: Neural Network (no_odds) (0.6344)
# INFO:src.metrics:🏅 Best model for Brier Score: Neural Network (no_odds) (0.2291)
# INFO:src.metrics:🏅 Best model for MCC: Logistic Regression (no_odds) (0.2045)
# INFO:src.metrics:🏅 Best model for Kappa: Logistic Regression (no_odds) (0.1889)
#                Metric                                 Best Model   Value
# 0            Accuracy              Logistic Regression (no_odds)  0.6278
# 1   Balanced Accuracy  Quadratic Discriminant Analysis (no_odds)  0.5906
# 2       Precision Red                      Naive Bayes (no_odds)  0.6468
# 3          Recall Red           Support Vector Machine (no_odds)  0.8981
# 4              F1 Red           Support Vector Machine (no_odds)  0.7369
# 5      Precision Blue           Support Vector Machine (no_odds)  0.6432
# 6         Recall Blue                      Naive Bayes (no_odds)  0.6111
# 7             F1 Blue                      Naive Bayes (no_odds)  0.5357
# 8            F1 Macro  Quadratic Discriminant Analysis (no_odds)  0.5895
# 9             ROC AUC                   Neural Network (no_odds)  0.6344
# 10        Brier Score                   Neural Network (no_odds)  0.2291
# 11                MCC              Logistic Regression (no_odds)  0.2045
# 12              Kappa              Logistic Regression (no_odds)  0.1889

# %% [markdown]
# ## Feature Importance

# %%
feature_names_with_odds = ufc_data.get_processed_train()[0].columns.tolist()
feature_names_no_odds = ufc_data_no_odds.get_processed_train()[0].columns.tolist()

# %%
UFCModel.plot_feature_importances_grid(
    models_with_odds,
    feature_names=feature_names_with_odds,
    save_file=True,
    filename='Feature-importance-with-odds'
)
# Out:
# INFO:src.model:✅ Plot saved to: /home/mlioi/ufc-predictor/img/Feature-importance-with-odds

# %%
UFCModel.plot_feature_importances_grid(
    models_no_odds,
    feature_names=feature_names_no_odds,
    save_file=True,
    filename='Feature-importance-no-odds'
)
# Out:
# INFO:src.model:✅ Plot saved to: /home/mlioi/ufc-predictor/img/Feature-importance-no-odds

# %%
ufc_data.plot_feature_distributions(processed=True)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# <div style="text-align: center;">
#      <img src="../img/ufc_logo.png" width="800" />
# </div>
